# %% [markdown]
# # Read csv(ratings_only file) and make tables with ID.

# %%
import pandas as pd
import json

# %%
def read_ratingsonly(path):
    
    df=pd.read_csv(path, sep=',',header=None)
    return df

#from stackoverflow
def remove_duplicates(values):
    output = []
    seen = set()
    for value in values:
        # If value has not been encountered yet,
        # ... add it to both list and set.
        if value not in seen:
            output.append(value)
            seen.add(value)
    return output

def write_userid(df,path):
    res = list()
    for i in range(0,len(df)):
        #df[0][i] -> ID.
        res.append(df[0][i])
    res = remove_duplicates(res)
    res = sorted(res)
    with open(path, 'w') as outfile:
        json.dump(res, outfile)

# %%
write_userid(read_ratingsonly('ratings_Health_and_Personal_Care.csv'),'health_userid.json')

# %%
with open('health_userid.json') as data_file:    
    data = json.load(data_file)
print len(data)
#data -> ID list.
# Out:
# 1851132

# %%
df
# Out:
#                       0           1  2           3
# 0        A3R5OBKS7OM2IR  0000143502  5  1358380800
# 1        A3R5OBKS7OM2IR  0000143529  5  1380672000
# 2         AH3QC2PC1VTGP  0000143561  2  1216252800
# 3        A3LKP6WPMP9UKX  0000143588  5  1236902400
# 4         AVIY68KEPQ5ZD  0000143588  5  1232236800
# 5        A1CV1WROP5KTTW  0000589012  5  1309651200
# 6         AP57WZ2X4G0AA  0000589012  2  1366675200
# 7        A3NMBJ2LCRCATT  0000589012  5  1393804800
# 8         A5Y15SAOMX6XA  0000589012  2  1307404800
# 9        A3P671HJ32TCSF  0000589012  5  1393718400
# 10       A3VCKTRD24BG7K  0000589012  5  1378425600
# 11        ANF0AGIV0JCH2  0000589012  5  1308182400
# 12       A3LDEBLV6MVUBE  0000589012  5  1208995200
# 13       A1R2XZWQ6NM5M1  0000589012  5  1224979200
# 14       A36L1XGA5AQIJY  0000589012  1  1393113600
# 15       A2HWI21H23GDS4  0000589012  4  1338681600
# 16       A1DNYFL3RSXRMO  0000589012  5  1208908800
# ...
